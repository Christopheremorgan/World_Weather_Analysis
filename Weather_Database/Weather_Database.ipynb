# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 779

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | pogar
# Processing Record 3 of Set 1 | kamenka
# Processing Record 4 of Set 1 | oblesevo
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 1 | lagoa
# Processing Record 8 of Set 1 | hearst
# Processing Record 9 of Set 1 | mecca
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | newport
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | mandera
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | tiarei
# Processing Record 18 of Set 1 | quatre cocos
# Processing Record 19 of Set 1 | bethel
# Processing Record 20 of Set 1 | presidencia roque saenz pena
# Processing Record 21 of Set 1 | mgachi
# Processing Record 22 of Set 1 | turukhansk
# Processing Record 23 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | mikhaylovka
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | puerto escondido
# Processing Record 31 of Set 1 | keuruu
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | bela
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | mandalgovi
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | veraval
# Processing Record 40 of Set 1 | nizwa
# Processing Record 41 of Set 1 | nemuro
# Processing Record 42 of Set 1 | faya
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | bemidji
# Processing Record 46 of Set 1 | bambous virieux
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | kirensk
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | puerto del rosario
# Processing Record 1 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 2 | maizuru
# Processing Record 3 of Set 2 | warner robins
# Processing Record 4 of Set 2 | hofn
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | chuy
# Processing Record 9 of Set 2 | grand gaube
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | toamasina
# Processing Record 12 of Set 2 | forbes
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | villafranca de los barros
# Processing Record 15 of Set 2 | bathsheba
# Processing Record 16 of Set 2 | dingle
# Processing Record 17 of Set 2 | elizabeth city
# Processing Record 18 of Set 2 | portland
# Processing Record 19 of Set 2 | gilgil
# City not found. Skipping...
# Processing Record 20 of Set 2 | coquimbo
# Processing Record 21 of Set 2 | hashtrud
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | vila franca do campo
# Processing Record 24 of Set 2 | los reyes
# Processing Record 25 of Set 2 | salihorsk
# Processing Record 26 of Set 2 | koslan
# Processing Record 27 of Set 2 | laguna
# Processing Record 28 of Set 2 | kaitangata
# Processing Record 29 of Set 2 | padang
# Processing Record 30 of Set 2 | nikolskoye
# Processing Record 31 of Set 2 | samarai
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | butaritari
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | buchanan
# Processing Record 36 of Set 2 | tuktoyaktuk
# Processing Record 37 of Set 2 | whitehorse
# Processing Record 38 of Set 2 | jiayuguan
# Processing Record 39 of Set 2 | lensk
# Processing Record 40 of Set 2 | leningradskiy
# Processing Record 41 of Set 2 | oskemen
# Processing Record 42 of Set 2 | kloulklubed
# Processing Record 43 of Set 2 | palmer
# Processing Record 44 of Set 2 | beroroha
# Processing Record 45 of Set 2 | saldanha
# Processing Record 46 of Set 2 | salalah
# Processing Record 47 of Set 2 | hasaki
# Processing Record 48 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 2 | jamestown
# Processing Record 50 of Set 2 | egvekinot
# Processing Record 1 of Set 3 | mahebourg
# Processing Record 2 of Set 3 | soligalich
# Processing Record 3 of Set 3 | cape town
# Processing Record 4 of Set 3 | hualmay
# Processing Record 5 of Set 3 | alice springs
# Processing Record 6 of Set 3 | clyde river
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | vardo
# Processing Record 10 of Set 3 | olavarria
# Processing Record 11 of Set 3 | victoria
# Processing Record 12 of Set 3 | saint george
# Processing Record 13 of Set 3 | guerrero negro
# Processing Record 14 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 3 | provideniya
# Processing Record 16 of Set 3 | atar
# Processing Record 17 of Set 3 | geraldton
# Processing Record 18 of Set 3 | hamilton
# Processing Record 19 of Set 3 | upernavik
# Processing Record 20 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 3 | mehamn
# Processing Record 22 of Set 3 | koltubanovskiy
# Processing Record 23 of Set 3 | nelson bay
# Processing Record 24 of Set 3 | arlit
# Processing Record 25 of Set 3 | bilibino
# Processing Record 26 of Set 3 | sao filipe
# Processing Record 27 of Set 3 | broome
# Processing Record 28 of Set 3 | pentecoste
# Processing Record 29 of Set 3 | santa flavia
# Processing Record 30 of Set 3 | cabo san lucas
# Processing Record 31 of Set 3 | tiksi
# Processing Record 32 of Set 3 | faanui
# Processing Record 33 of Set 3 | izhma
# Processing Record 34 of Set 3 | beloha
# Processing Record 35 of Set 3 | mount isa
# Processing Record 36 of Set 3 | hibbing
# Processing Record 37 of Set 3 | tacoronte
# Processing Record 38 of Set 3 | harelbeke
# Processing Record 39 of Set 3 | deputatskiy
# Processing Record 40 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 3 | chokurdakh
# Processing Record 42 of Set 3 | santo antonio do ica
# Processing Record 43 of Set 3 | porto novo
# Processing Record 44 of Set 3 | mwinilunga
# Processing Record 45 of Set 3 | torbay
# Processing Record 46 of Set 3 | lompoc
# Processing Record 47 of Set 3 | ribeira grande
# Processing Record 48 of Set 3 | orissaare
# Processing Record 49 of Set 3 | chumikan
# Processing Record 50 of Set 3 | severo-kurilsk
# Processing Record 1 of Set 4 | cururupu
# Processing Record 2 of Set 4 | grindavik
# Processing Record 3 of Set 4 | airai
# Processing Record 4 of Set 4 | juneau
# Processing Record 5 of Set 4 | remedios
# Processing Record 6 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 4 | altay
# Processing Record 8 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 4 | ancud
# Processing Record 10 of Set 4 | roald
# Processing Record 11 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 4 | arraial do cabo
# Processing Record 13 of Set 4 | bontang
# Processing Record 14 of Set 4 | santa rosa de cabal
# Processing Record 15 of Set 4 | piranhas
# Processing Record 16 of Set 4 | westport
# Processing Record 17 of Set 4 | kearney
# Processing Record 18 of Set 4 | hukuntsi
# Processing Record 19 of Set 4 | gulshat
# City not found. Skipping...
# Processing Record 20 of Set 4 | saint-denis
# Processing Record 21 of Set 4 | sumbe
# Processing Record 22 of Set 4 | dunedin
# Processing Record 23 of Set 4 | cidreira
# Processing Record 24 of Set 4 | yatou
# Processing Record 25 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 26 of Set 4 | sakakah
# Processing Record 27 of Set 4 | biograd na moru
# Processing Record 28 of Set 4 | angoram
# Processing Record 29 of Set 4 | mumford
# Processing Record 30 of Set 4 | ust-maya
# Processing Record 31 of Set 4 | wanxian
# Processing Record 32 of Set 4 | santa maria
# Processing Record 33 of Set 4 | porto santo
# Processing Record 34 of Set 4 | alibag
# Processing Record 35 of Set 4 | ostersund
# Processing Record 36 of Set 4 | virginia beach
# Processing Record 37 of Set 4 | georgetown
# Processing Record 38 of Set 4 | port hardy
# Processing Record 39 of Set 4 | myre
# Processing Record 40 of Set 4 | ahipara
# Processing Record 41 of Set 4 | bay roberts
# Processing Record 42 of Set 4 | castro
# Processing Record 43 of Set 4 | songjianghe
# Processing Record 44 of Set 4 | mangrol
# Processing Record 45 of Set 4 | darhan
# Processing Record 46 of Set 4 | klaksvik
# Processing Record 47 of Set 4 | itarema
# Processing Record 48 of Set 4 | inta
# Processing Record 49 of Set 4 | le mans
# Processing Record 50 of Set 4 | matagami
# Processing Record 1 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 2 of Set 5 | codrington
# Processing Record 3 of Set 5 | iskateley
# Processing Record 4 of Set 5 | caceres
# Processing Record 5 of Set 5 | santander
# Processing Record 6 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 5 | rio gallegos
# Processing Record 8 of Set 5 | honningsvag
# Processing Record 9 of Set 5 | naberera
# Processing Record 10 of Set 5 | thompson
# Processing Record 11 of Set 5 | salvador
# Processing Record 12 of Set 5 | longyearbyen
# Processing Record 13 of Set 5 | belyy yar
# Processing Record 14 of Set 5 | taltal
# Processing Record 15 of Set 5 | san patricio
# Processing Record 16 of Set 5 | skelleftea
# Processing Record 17 of Set 5 | ambon
# Processing Record 18 of Set 5 | yaan
# Processing Record 19 of Set 5 | anchorage
# Processing Record 20 of Set 5 | gao
# Processing Record 21 of Set 5 | sungaipenuh
# Processing Record 22 of Set 5 | atambua
# Processing Record 23 of Set 5 | distraccion
# Processing Record 24 of Set 5 | vitoria da conquista
# Processing Record 25 of Set 5 | tuatapere
# Processing Record 26 of Set 5 | colares
# Processing Record 27 of Set 5 | mount gambier
# Processing Record 28 of Set 5 | nanortalik
# Processing Record 29 of Set 5 | durango
# Processing Record 30 of Set 5 | charters towers
# Processing Record 31 of Set 5 | kruisfontein
# Processing Record 32 of Set 5 | muisne
# Processing Record 33 of Set 5 | plover
# Processing Record 34 of Set 5 | ormara
# Processing Record 35 of Set 5 | burica
# City not found. Skipping...
# Processing Record 36 of Set 5 | chernyshevskiy
# Processing Record 37 of Set 5 | nouakchott
# Processing Record 38 of Set 5 | acapulco
# Processing Record 39 of Set 5 | alta floresta
# Processing Record 40 of Set 5 | saint-pierre
# Processing Record 41 of Set 5 | ushibuka
# Processing Record 42 of Set 5 | dikson
# Processing Record 43 of Set 5 | shambu
# Processing Record 44 of Set 5 | talnakh
# Processing Record 45 of Set 5 | armacao dos buzios
# City not found. Skipping...
# Processing Record 46 of Set 5 | xining
# Processing Record 47 of Set 5 | barentu
# Processing Record 48 of Set 5 | adre
# Processing Record 49 of Set 5 | acarau
# Processing Record 50 of Set 5 | centralia
# Processing Record 1 of Set 6 | khatanga
# Processing Record 2 of Set 6 | dawei
# Processing Record 3 of Set 6 | marakkanam
# Processing Record 4 of Set 6 | mitsamiouli
# Processing Record 5 of Set 6 | marzuq
# Processing Record 6 of Set 6 | boulder
# Processing Record 7 of Set 6 | klyuchi
# Processing Record 8 of Set 6 | puerto madero
# Processing Record 9 of Set 6 | uvat
# Processing Record 10 of Set 6 | ponta delgada
# Processing Record 11 of Set 6 | qui nhon
# Processing Record 12 of Set 6 | kladno
# Processing Record 13 of Set 6 | saint-louis
# Processing Record 14 of Set 6 | ushtobe
# Processing Record 15 of Set 6 | esperance
# Processing Record 16 of Set 6 | saint-augustin
# Processing Record 17 of Set 6 | vostok
# Processing Record 18 of Set 6 | yar-sale
# Processing Record 19 of Set 6 | half moon bay
# Processing Record 20 of Set 6 | brae
# Processing Record 21 of Set 6 | novokizhinginsk
# Processing Record 22 of Set 6 | donskoye
# Processing Record 23 of Set 6 | conceicao do araguaia
# Processing Record 24 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 6 | oranjemund
# Processing Record 26 of Set 6 | sisimiut
# Processing Record 27 of Set 6 | kilrush
# Processing Record 28 of Set 6 | becerril
# Processing Record 29 of Set 6 | isiro
# Processing Record 30 of Set 6 | manhattan
# Processing Record 31 of Set 6 | yulara
# Processing Record 32 of Set 6 | qandala
# Processing Record 33 of Set 6 | hami
# Processing Record 34 of Set 6 | cefalu
# Processing Record 35 of Set 6 | bandiagara
# Processing Record 36 of Set 6 | kahului
# Processing Record 37 of Set 6 | kidal
# Processing Record 38 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 6 | byron bay
# Processing Record 40 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 6 | batagay-alyta
# Processing Record 42 of Set 6 | cumberland
# Processing Record 43 of Set 6 | haimen
# Processing Record 44 of Set 6 | bengkulu
# Processing Record 45 of Set 6 | mingaora
# Processing Record 46 of Set 6 | conceicao do rio verde
# Processing Record 47 of Set 6 | seddon
# Processing Record 48 of Set 6 | poya
# Processing Record 49 of Set 6 | san cristobal
# Processing Record 50 of Set 6 | mocuba
# Processing Record 1 of Set 7 | maragogi
# Processing Record 2 of Set 7 | lasa
# Processing Record 3 of Set 7 | saskylakh
# Processing Record 4 of Set 7 | bulgan
# Processing Record 5 of Set 7 | ust-kan
# Processing Record 6 of Set 7 | carmen
# Processing Record 7 of Set 7 | gizo
# Processing Record 8 of Set 7 | aosta
# Processing Record 9 of Set 7 | barcelos
# Processing Record 10 of Set 7 | fortuna
# Processing Record 11 of Set 7 | ryotsu
# Processing Record 12 of Set 7 | belmonte
# Processing Record 13 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 7 | mantua
# Processing Record 15 of Set 7 | cherskiy
# Processing Record 16 of Set 7 | mana
# Processing Record 17 of Set 7 | narsipatnam
# Processing Record 18 of Set 7 | la ronge
# Processing Record 19 of Set 7 | banda aceh
# Processing Record 20 of Set 7 | port blair
# Processing Record 21 of Set 7 | chingirlau
# Processing Record 22 of Set 7 | pyay
# Processing Record 23 of Set 7 | margate
# Processing Record 24 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 7 | carutapera
# Processing Record 26 of Set 7 | kharian
# Processing Record 27 of Set 7 | bocaranga
# City not found. Skipping...
# Processing Record 28 of Set 7 | lavumisa
# Processing Record 29 of Set 7 | yamada
# Processing Record 30 of Set 7 | narsaq
# Processing Record 31 of Set 7 | bocas del toro
# Processing Record 32 of Set 7 | auki
# Processing Record 33 of Set 7 | wick
# Processing Record 34 of Set 7 | pontarlier
# Processing Record 35 of Set 7 | carnarvon
# Processing Record 36 of Set 7 | ratangarh
# Processing Record 37 of Set 7 | seymchan
# Processing Record 38 of Set 7 | katherine
# Processing Record 39 of Set 7 | vila
# Processing Record 40 of Set 7 | sambava
# Processing Record 41 of Set 7 | barhi
# Processing Record 42 of Set 7 | jakhal mandi
# City not found. Skipping...
# Processing Record 43 of Set 7 | morro bay
# Processing Record 44 of Set 7 | kandana
# Processing Record 45 of Set 7 | comodoro rivadavia
# Processing Record 46 of Set 7 | ati
# Processing Record 47 of Set 7 | rawson
# Processing Record 48 of Set 7 | port macquarie
# Processing Record 49 of Set 7 | pisco
# Processing Record 50 of Set 7 | eyl
# Processing Record 1 of Set 8 | bojnurd
# Processing Record 2 of Set 8 | verkhnevilyuysk
# Processing Record 3 of Set 8 | chugunash
# City not found. Skipping...
# Processing Record 4 of Set 8 | walvis bay
# Processing Record 5 of Set 8 | praia
# Processing Record 6 of Set 8 | zyryanka
# Processing Record 7 of Set 8 | fare
# Processing Record 8 of Set 8 | oneonta
# Processing Record 9 of Set 8 | vitorino freire
# Processing Record 10 of Set 8 | kangaatsiaq
# Processing Record 11 of Set 8 | teguise
# Processing Record 12 of Set 8 | erzin
# Processing Record 13 of Set 8 | ponta do sol
# Processing Record 14 of Set 8 | port hedland
# Processing Record 15 of Set 8 | kajaani
# Processing Record 16 of Set 8 | lexington
# Processing Record 17 of Set 8 | batemans bay
# Processing Record 18 of Set 8 | itaituba
# Processing Record 19 of Set 8 | medicine hat
# Processing Record 20 of Set 8 | valdivia
# Processing Record 21 of Set 8 | kodiak
# Processing Record 22 of Set 8 | myitkyina
# Processing Record 23 of Set 8 | phnum penh
# City not found. Skipping...
# Processing Record 24 of Set 8 | tsaratanana
# Processing Record 25 of Set 8 | yuci
# Processing Record 26 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 8 | limpapa
# Processing Record 28 of Set 8 | sao paulo de olivenca
# Processing Record 29 of Set 8 | kavaratti
# Processing Record 30 of Set 8 | kudahuvadhoo
# Processing Record 31 of Set 8 | norman wells
# Processing Record 32 of Set 8 | akyab
# Processing Record 33 of Set 8 | plettenberg bay
# Processing Record 34 of Set 8 | banyo
# Processing Record 35 of Set 8 | sabha
# Processing Record 36 of Set 8 | davila
# Processing Record 37 of Set 8 | sao joao da barra
# Processing Record 38 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 39 of Set 8 | san carlos de bariloche
# Processing Record 40 of Set 8 | necochea
# Processing Record 41 of Set 8 | namtsy
# Processing Record 42 of Set 8 | havoysund
# Processing Record 43 of Set 8 | atbasar
# Processing Record 44 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 8 | flinders
# Processing Record 46 of Set 8 | yangambi
# Processing Record 47 of Set 8 | olafsvik
# Processing Record 48 of Set 8 | tiznit
# Processing Record 49 of Set 8 | panguna
# Processing Record 50 of Set 8 | ankpa
# Processing Record 1 of Set 9 | werda
# Processing Record 2 of Set 9 | sept-iles
# Processing Record 3 of Set 9 | garchitorena
# Processing Record 4 of Set 9 | brooks
# Processing Record 5 of Set 9 | nueve de julio
# Processing Record 6 of Set 9 | souillac
# Processing Record 7 of Set 9 | tual
# Processing Record 8 of Set 9 | benguela
# Processing Record 9 of Set 9 | khani
# Processing Record 10 of Set 9 | kotma
# Processing Record 11 of Set 9 | sioux lookout
# Processing Record 12 of Set 9 | wasilla
# Processing Record 13 of Set 9 | avera
# Processing Record 14 of Set 9 | yanam
# Processing Record 15 of Set 9 | isla vista
# Processing Record 16 of Set 9 | beyneu
# Processing Record 17 of Set 9 | isangel
# Processing Record 18 of Set 9 | nguru
# Processing Record 19 of Set 9 | uwayl
# City not found. Skipping...
# Processing Record 20 of Set 9 | kapit
# Processing Record 21 of Set 9 | ulaangom
# Processing Record 22 of Set 9 | dibulla
# Processing Record 23 of Set 9 | marica
# Processing Record 24 of Set 9 | colesberg
# Processing Record 25 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 9 | hobyo
# Processing Record 27 of Set 9 | bambanglipuro
# Processing Record 28 of Set 9 | masallatah
# Processing Record 29 of Set 9 | japura
# Processing Record 30 of Set 9 | ngunguru
# Processing Record 31 of Set 9 | estevan
# Processing Record 32 of Set 9 | arzgir
# Processing Record 33 of Set 9 | guozhen
# Processing Record 34 of Set 9 | pingliang
# Processing Record 35 of Set 9 | coihaique
# Processing Record 36 of Set 9 | fairbanks
# Processing Record 37 of Set 9 | kosa
# Processing Record 38 of Set 9 | tura
# Processing Record 39 of Set 9 | beian
# Processing Record 40 of Set 9 | srednekolymsk
# Processing Record 41 of Set 9 | kushima
# Processing Record 42 of Set 9 | lebu
# Processing Record 43 of Set 9 | ballina
# Processing Record 44 of Set 9 | muskegon
# Processing Record 45 of Set 9 | kumeny
# Processing Record 46 of Set 9 | korla
# Processing Record 47 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 9 | namatanai
# Processing Record 49 of Set 9 | tateyama
# Processing Record 50 of Set 9 | saint-hubert
# Processing Record 1 of Set 10 | manzanillo
# Processing Record 2 of Set 10 | ilulissat
# Processing Record 3 of Set 10 | north versailles
# Processing Record 4 of Set 10 | lisakovsk
# Processing Record 5 of Set 10 | nioro
# Processing Record 6 of Set 10 | ust-nera
# Processing Record 7 of Set 10 | nizhniy chir
# Processing Record 8 of Set 10 | iqaluit
# Processing Record 9 of Set 10 | lavassaare
# Processing Record 10 of Set 10 | tokmak
# Processing Record 11 of Set 10 | tacarigua
# Processing Record 12 of Set 10 | odienne
# Processing Record 13 of Set 10 | hay river
# Processing Record 14 of Set 10 | bahia blanca
# Processing Record 15 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 16 of Set 10 | komsomolskiy
# Processing Record 17 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 18 of Set 10 | haileybury
# Processing Record 19 of Set 10 | hovd
# Processing Record 20 of Set 10 | sorland
# Processing Record 21 of Set 10 | chitral
# Processing Record 22 of Set 10 | le port
# Processing Record 23 of Set 10 | tuy hoa
# Processing Record 24 of Set 10 | taoudenni
# Processing Record 25 of Set 10 | yarada
# Processing Record 26 of Set 10 | baljevac
# Processing Record 27 of Set 10 | natchez
# Processing Record 28 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 29 of Set 10 | umm kaddadah
# Processing Record 30 of Set 10 | gotsu
# Processing Record 31 of Set 10 | katsuura
# Processing Record 32 of Set 10 | lannion
# Processing Record 33 of Set 10 | bandarbeyla
# Processing Record 34 of Set 10 | balikpapan
# Processing Record 35 of Set 10 | marsh harbour
# Processing Record 36 of Set 10 | pevek
# Processing Record 37 of Set 10 | vikulovo
# Processing Record 38 of Set 10 | muravlenko
# Processing Record 39 of Set 10 | kiunga
# Processing Record 40 of Set 10 | lima
# Processing Record 41 of Set 10 | praia da vitoria
# Processing Record 42 of Set 10 | port augusta
# Processing Record 43 of Set 10 | west monroe
# Processing Record 44 of Set 10 | nchelenge
# Processing Record 45 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 46 of Set 10 | tutoia
# Processing Record 47 of Set 10 | sinjar
# Processing Record 48 of Set 10 | aklavik
# Processing Record 49 of Set 10 | bubaque
# Processing Record 50 of Set 10 | miraflores
# Processing Record 1 of Set 11 | mackay
# Processing Record 2 of Set 11 | la montanita
# Processing Record 3 of Set 11 | goundam
# Processing Record 4 of Set 11 | yumbel
# Processing Record 5 of Set 11 | san andres
# Processing Record 6 of Set 11 | kenai
# Processing Record 7 of Set 11 | kuryk
# Processing Record 8 of Set 11 | bonfim
# Processing Record 9 of Set 11 | cockburn town
# Processing Record 10 of Set 11 | thasra
# Processing Record 11 of Set 11 | whitianga
# Processing Record 12 of Set 11 | longhua
# Processing Record 13 of Set 11 | zhigansk
# Processing Record 14 of Set 11 | ambunti
# Processing Record 15 of Set 11 | monrovia
# Processing Record 16 of Set 11 | cayenne
# Processing Record 17 of Set 11 | chipinge
# Processing Record 18 of Set 11 | port-gentil
# Processing Record 19 of Set 11 | poum
# Processing Record 20 of Set 11 | minggang
# Processing Record 21 of Set 11 | sijunjung
# Processing Record 22 of Set 11 | timmins
# Processing Record 23 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 11 | verkhnyaya inta
# Processing Record 25 of Set 11 | lorengau
# Processing Record 26 of Set 11 | lisala
# Processing Record 27 of Set 11 | muta
# Processing Record 28 of Set 11 | gat
# Processing Record 29 of Set 11 | khonsa
# Processing Record 30 of Set 11 | tucuma
# Processing Record 31 of Set 11 | the pas
# Processing Record 32 of Set 11 | te anau
# Processing Record 33 of Set 11 | pacific grove
# Processing Record 34 of Set 11 | lalsk
# Processing Record 35 of Set 11 | fethiye
# Processing Record 36 of Set 11 | oranjestad
# Processing Record 37 of Set 11 | ziro
# Processing Record 38 of Set 11 | sao lourenco do sul
# Processing Record 39 of Set 11 | cap malheureux
# Processing Record 40 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 41 of Set 11 | srandakan
# Processing Record 42 of Set 11 | wanning
# Processing Record 43 of Set 11 | denpasar
# Processing Record 44 of Set 11 | umm lajj
# Processing Record 45 of Set 11 | chkalovsk
# Processing Record 46 of Set 11 | cap-aux-meules
# Processing Record 47 of Set 11 | opuwo
# Processing Record 48 of Set 11 | grenfell
# Processing Record 49 of Set 11 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 50 of Set 11 | gilgit
# Processing Record 1 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 12 | wladyslawowo
# Processing Record 3 of Set 12 | autazes
# Processing Record 4 of Set 12 | nishihara
# Processing Record 5 of Set 12 | bluefield
# Processing Record 6 of Set 12 | wewak
# Processing Record 7 of Set 12 | chapais
# Processing Record 8 of Set 12 | marawi
# Processing Record 9 of Set 12 | bakong
# Processing Record 10 of Set 12 | asau
# Processing Record 11 of Set 12 | north bend
# Processing Record 12 of Set 12 | bam
# Processing Record 13 of Set 12 | iracoubo
# Processing Record 14 of Set 12 | kalmunai
# Processing Record 15 of Set 12 | tir pol
# City not found. Skipping...
# Processing Record 16 of Set 12 | constantine
# Processing Record 17 of Set 12 | synya
# Processing Record 18 of Set 12 | miri
# Processing Record 19 of Set 12 | zhezkazgan
# Processing Record 20 of Set 12 | jesup
# Processing Record 21 of Set 12 | nosivka
# Processing Record 22 of Set 12 | kamaishi
# Processing Record 23 of Set 12 | wakkanai
# Processing Record 24 of Set 12 | aswan
# Processing Record 25 of Set 12 | vangaindrano
# Processing Record 26 of Set 12 | broken hill
# Processing Record 27 of Set 12 | qeshm
# Processing Record 28 of Set 12 | tazovskiy
# Processing Record 29 of Set 12 | kununurra
# Processing Record 30 of Set 12 | sosnovo-ozerskoye
# Processing Record 31 of Set 12 | karasjok
# Processing Record 32 of Set 12 | bardsir
# Processing Record 33 of Set 12 | vila velha
# Processing Record 34 of Set 12 | tomatlan
# Processing Record 35 of Set 12 | los llanos de aridane
# Processing Record 36 of Set 12 | birmitrapur
# Processing Record 37 of Set 12 | yei
# Processing Record 38 of Set 12 | katobu
# Processing Record 39 of Set 12 | cordoba
# Processing Record 40 of Set 12 | haines junction
# Processing Record 41 of Set 12 | carmelo
# Processing Record 42 of Set 12 | vestmanna
# Processing Record 43 of Set 12 | presidente dutra
# Processing Record 44 of Set 12 | boo
# Processing Record 45 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 12 | berlevag
# Processing Record 47 of Set 12 | sitka
# Processing Record 48 of Set 12 | lambare
# Processing Record 49 of Set 12 | anadyr
# Processing Record 50 of Set 12 | pipar
# Processing Record 1 of Set 13 | vestmannaeyjar
# Processing Record 2 of Set 13 | ordynskoye
# Processing Record 3 of Set 13 | flin flon
# Processing Record 4 of Set 13 | bairiki
# Processing Record 5 of Set 13 | rabo de peixe
# Processing Record 6 of Set 13 | tucuman
# Processing Record 7 of Set 13 | elk plain
# Processing Record 8 of Set 13 | along
# Processing Record 9 of Set 13 | sibot
# Processing Record 10 of Set 13 | buckeye
# Processing Record 11 of Set 13 | ostrovnoy
# Processing Record 12 of Set 13 | beringovskiy
# Processing Record 13 of Set 13 | nome
# Processing Record 14 of Set 13 | hobe sound
# Processing Record 15 of Set 13 | olga
# Processing Record 16 of Set 13 | grootfontein
# Processing Record 17 of Set 13 | zmeinogorsk
# Processing Record 18 of Set 13 | kemijarvi
# Processing Record 19 of Set 13 | maracena
# Processing Record 20 of Set 13 | sidi ali
# Processing Record 21 of Set 13 | chifeng
# Processing Record 22 of Set 13 | unguia
# Processing Record 23 of Set 13 | evanston
# Processing Record 24 of Set 13 | pinheiro machado
# Processing Record 25 of Set 13 | alenquer
# Processing Record 26 of Set 13 | saint anthony
# Processing Record 27 of Set 13 | lavrentiya
# Processing Record 28 of Set 13 | constitucion
# Processing Record 29 of Set 13 | porto murtinho
# Processing Record 30 of Set 13 | evensk
# Processing Record 31 of Set 13 | mwanza
# Processing Record 32 of Set 13 | cabedelo
# Processing Record 33 of Set 13 | dosso
# Processing Record 34 of Set 13 | kijang
# Processing Record 35 of Set 13 | gujranwala
# Processing Record 36 of Set 13 | lukino
# Processing Record 37 of Set 13 | victoria point
# Processing Record 38 of Set 13 | russell
# Processing Record 39 of Set 13 | rio grande
# Processing Record 40 of Set 13 | youkounkoun
# Processing Record 41 of Set 13 | kavieng
# Processing Record 42 of Set 13 | teknaf
# Processing Record 43 of Set 13 | mindelo
# Processing Record 44 of Set 13 | shekhupura
# Processing Record 45 of Set 13 | shelburne
# Processing Record 46 of Set 13 | taunggyi
# Processing Record 47 of Set 13 | fort walton beach
# Processing Record 48 of Set 13 | luanda
# Processing Record 49 of Set 13 | la joya
# Processing Record 50 of Set 13 | elk river
# Processing Record 1 of Set 14 | bayir
# Processing Record 2 of Set 14 | havre-saint-pierre
# Processing Record 3 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 14 | nguruka
# Processing Record 5 of Set 14 | khailar
# Processing Record 6 of Set 14 | nhulunbuy
# Processing Record 7 of Set 14 | makakilo city
# Processing Record 8 of Set 14 | koygorodok
# Processing Record 9 of Set 14 | meulaboh
# Processing Record 10 of Set 14 | itoman
# Processing Record 11 of Set 14 | marfino
# Processing Record 12 of Set 14 | murray bridge
# Processing Record 13 of Set 14 | mildura
# Processing Record 14 of Set 14 | harduaganj
# Processing Record 15 of Set 14 | banff
# Processing Record 16 of Set 14 | saint-francois
# Processing Record 17 of Set 14 | baykit
# Processing Record 18 of Set 14 | cravo norte
# Processing Record 19 of Set 14 | tara
# Processing Record 20 of Set 14 | barnstaple
# Processing Record 21 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 14 | gimli
# Processing Record 23 of Set 14 | husavik
# Processing Record 24 of Set 14 | cabinda
# Processing Record 25 of Set 14 | tadine
# Processing Record 26 of Set 14 | el wasta
# City not found. Skipping...
# Processing Record 27 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 14 | namibe
# Processing Record 29 of Set 14 | pontianak
# Processing Record 30 of Set 14 | imeni poliny osipenko
# Processing Record 31 of Set 14 | khrebtovaya
# Processing Record 32 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 14 | douentza
# Processing Record 34 of Set 14 | abha
# Processing Record 35 of Set 14 | porto de moz
# Processing Record 36 of Set 14 | dongsheng
# Processing Record 37 of Set 14 | zhanakorgan
# Processing Record 38 of Set 14 | talaya
# Processing Record 39 of Set 14 | klyuchevskiy
# Processing Record 40 of Set 14 | thio
# Processing Record 41 of Set 14 | halifax
# Processing Record 42 of Set 14 | kathu
# Processing Record 43 of Set 14 | port lavaca
# Processing Record 44 of Set 14 | ballarat
# Processing Record 45 of Set 14 | port lincoln
# Processing Record 46 of Set 14 | armidale
# Processing Record 47 of Set 14 | pringsewu
# Processing Record 48 of Set 14 | poso
# Processing Record 49 of Set 14 | teluk nibung
# Processing Record 50 of Set 14 | tres lagoas
# Processing Record 1 of Set 15 | nkowakowa
# Processing Record 2 of Set 15 | brewster
# Processing Record 3 of Set 15 | awbari
# Processing Record 4 of Set 15 | buncrana
# Processing Record 5 of Set 15 | alofi
# Processing Record 6 of Set 15 | jibuti
# Processing Record 7 of Set 15 | nehe
# Processing Record 8 of Set 15 | boguchany
# Processing Record 9 of Set 15 | salisbury
# Processing Record 10 of Set 15 | umba
# Processing Record 11 of Set 15 | mareeba
# Processing Record 12 of Set 15 | puri
# Processing Record 13 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 14 of Set 15 | karasburg
# Processing Record 15 of Set 15 | saraland
# Processing Record 16 of Set 15 | touros
# Processing Record 17 of Set 15 | san jeronimo
# Processing Record 18 of Set 15 | ewa beach
# Processing Record 19 of Set 15 | vanavara
# Processing Record 20 of Set 15 | roma
# Processing Record 21 of Set 15 | manggar
# Processing Record 22 of Set 15 | kushiro
# Processing Record 23 of Set 15 | rovaniemi
# Processing Record 24 of Set 15 | luderitz
# Processing Record 25 of Set 15 | burnie
# Processing Record 26 of Set 15 | rupert
# Processing Record 27 of Set 15 | lewiston
# Processing Record 28 of Set 15 | araouane
# Processing Record 29 of Set 15 | prince rupert
# Processing Record 30 of Set 15 | boende
# Processing Record 31 of Set 15 | zhanaozen
# Processing Record 32 of Set 15 | sola
# Processing Record 33 of Set 15 | agadez
# Processing Record 34 of Set 15 | hirara
# Processing Record 35 of Set 15 | mirabad
# Processing Record 36 of Set 15 | wattegama
# Processing Record 37 of Set 15 | jumla
# Processing Record 38 of Set 15 | orange
# Processing Record 39 of Set 15 | mayo
# Processing Record 40 of Set 15 | pemangkat
# Processing Record 41 of Set 15 | ikornnes
# Processing Record 42 of Set 15 | kichera
# Processing Record 43 of Set 15 | boralday
# Processing Record 44 of Set 15 | hailin
# Processing Record 45 of Set 15 | mastic beach
# Processing Record 46 of Set 15 | richards bay
# Processing Record 47 of Set 15 | shihezi
# Processing Record 48 of Set 15 | fort nelson
# Processing Record 49 of Set 15 | kouango
# Processing Record 50 of Set 15 | briancon
# Processing Record 1 of Set 16 | kachiry
# Processing Record 2 of Set 16 | taos
# Processing Record 3 of Set 16 | dubrovnik
# Processing Record 4 of Set 16 | college
# Processing Record 5 of Set 16 | woodward
# Processing Record 6 of Set 16 | tortoli
# Processing Record 7 of Set 16 | neryungri
# Processing Record 8 of Set 16 | danielskuil
# Processing Record 9 of Set 16 | olomouc
# Processing Record 10 of Set 16 | general roca
# Processing Record 11 of Set 16 | kaniama
# Processing Record 12 of Set 16 | emerald
# Processing Record 13 of Set 16 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 16 | lalmohan
# Processing Record 15 of Set 16 | severnoye
# Processing Record 16 of Set 16 | sao luiz gonzaga
# Processing Record 17 of Set 16 | okakarara
# Processing Record 18 of Set 16 | cozumel
# Processing Record 19 of Set 16 | labunista
# Processing Record 20 of Set 16 | sao jose da coroa grande
# Processing Record 21 of Set 16 | linares
# Processing Record 22 of Set 16 | ouadda
# Processing Record 23 of Set 16 | leninskoye
# Processing Record 24 of Set 16 | znamenskoye
# Processing Record 25 of Set 16 | kracheh
# City not found. Skipping...
# Processing Record 26 of Set 16 | bereda
# Processing Record 27 of Set 16 | hvammstangi
# City not found. Skipping...
# Processing Record 28 of Set 16 | guilin
# Processing Record 29 of Set 16 | marmora
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 725

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hobart      AU -42.8794  147.3294     54.27        91          40
# 1       Pogar      RU  52.5540   33.2591     55.02        83          38
# 2     Kamenka      RU  51.3223   42.7678     60.94        79         100
# 3    Oblesevo      MK  41.8833   22.3339     68.95        65          60
# 4       Kapaa      US  22.0752 -159.3190     78.78        68          40
# 5       Lagoa      PT  39.0500  -27.9833     59.38        61           5
# 6      Hearst      CA  49.6835  -83.6665     48.45        87         100
# 7       Mecca      SA  21.4267   39.8261     89.37        37           6
# 8  Bredasdorp      ZA -34.5322   20.0403     47.52        75          90
# 9     Rikitea      PF -23.1203 -134.9692     76.55        67          15
#
#    Wind Speed Current Description
# 0        2.35    scattered clouds
# 1        8.34    scattered clouds
# 2       12.39     overcast clouds
# 3        4.61       broken clouds
# 4        3.00    scattered clouds
# 5       11.34           clear sky
# 6        8.72     overcast clouds
# 7        6.08           clear sky
# 8        5.70     overcast clouds
# 9       12.57          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
